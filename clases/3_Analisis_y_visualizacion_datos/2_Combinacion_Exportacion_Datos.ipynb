# %% [markdown]
# <a href="https://colab.research.google.com/github/LinaMariaCastro/curso-ia-para-economia/blob/main/clases/3_Analisis_y_visualizacion_datos/2_Combinacion_Exportacion_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Inteligencia Artificial con Aplicaciones en Economía I**
#
# - 👩‍🏫 **Profesora:** [Lina María Castro](https://www.linkedin.com/in/lina-maria-castro)
# - 📧 **Email:** [lmcastroco@gmail.com](mailto:lmcastroco@gmail.com)
# - 🎓 **Universidad:** Universidad Externado de Colombia - Facultad de Economía

# %% [markdown]
# # 🛢️**Métodos de combinación y exportación de datos**

# %% [markdown]
# **Objetivos de Aprendizaje:**
#
# Al finalizar este notebook, serás capaz de:
# 1.  **Combinar múltiples datasets** de forma eficiente utilizando las funciones `concat` y `merge` de pandas.
# 2.  **Exportar tus DataFrames resultantes** a diversos formatos para su uso posterior.

# %% [markdown]
# ---

# %% [markdown]
# ## Importar librerías

# %%
import os
import numpy as np
import pandas as pd

# %% [markdown]
# ## Mejorar visualización de los dataframes

# %%
# Que muestre todas las columnas
pd.options.display.max_columns = None
# En los dataframes, mostrar los float con dos decimales
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## Establecer la ruta de los datasets

# %%
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/2026-i-curso-ia-para-economia/datasets'

# %%
# Para establecer el directorio de los archivos
os.chdir(path)

# %% [markdown]
# ---

# %% [markdown]
# ## Unir Datos con `pd.concat` y `pd.merge`
#
# Rara vez un proyecto de análisis económico se basa en una sola fuente de datos, por tanto, es muy importante saber combinar datasets de manera lógica y correcta.

# %% [markdown]
# ### Concatenación con `pd.concat()`
#
# `concat` nos permite "apilar" DataFrames uno encima del otro (eje 0) o uno al lado del otro (eje 1). Su uso más común es para agregar nuevas filas al DataFrame.
#
# **Ejemplo:** Eres un analista del DANE, de la Coordinación de Comercio Internacional, y tienes el archivo de las exportaciones de bienes de julio 2024. Al mes siguiente, recibes el archivo de agosto. `concat` es la acción de tomar las hojas del nuevo reporte y añadirlas al final del reporte del mes anterior. Esto se suele hacer con los archivos de enero a diciembre para construir un único archivo consolidado del año.

# %%
df_expo_jul = pd.read_excel('expo_bienes_2024/07_Exportaciones_2024_Julio.xlsx')
df_expo_jul.head(3)
# Out:
#    FECHA_PROCESO  NUMERO_SERIE  OFICINA  COD_ADUANA_DESPACHO  \
# 0         202407             7       99                   89
# 1         202407             6       99                   89
# 2         202407             5       99                   89
#
#      ADUANA_DESPACHO  TIPO_IDENT  NIT_EXPORTADOR  TIPO_USUARIO  COD_USUARIO  \
# 0  Aduanas de Cúcuta           2  901,333,018.00            36            0
# 1  Aduanas de Cúcuta           2  901,333,018.00            36            0
# 2  Aduanas de Cúcuta           2  901,333,018.00            36            0
#
#    CLASE_EXPORTADOR  COD_DPTO_EXPORTADOR  COD_PAIS_DESTINO_NUM  \
# 0                 2                54001                   850
# 1                 2                54001                   850
# 2                 2                54001                   850
#
#   COD_PAIS_DESTINO_ALF COD_PAIS_DESTINO                    PAIS_DESTINO_FINAL  \
# 0                  VEN               VE  VENEZUELA (REPÚBLICA BOLIVARIANA DE)
# 1                  VEN               VE  VENEZUELA (REPÚBLICA BOLIVARIANA DE)
# 2                  VEN               VE  VENEZUELA (REPÚBLICA BOLIVARIANA DE)
#
#   CIUDAD_DESTINATARIO  NUM_SOLICITUD_AUTO_EMBARQUE  TIPO_DECLARACION  \
# 0              MERIDA                6027733007951                 1
# 1              MERIDA                6027733007951                 1
# 2              MERIDA                6027733007951                 1
#
#   TIPO_DESPACHO  COD_LUGAR_SALIDA_NUM COD_LUG_SALIDA_ALF  \
# 0       Inicial                    89                CUC
# 1       Inicial                    89                CUC
# 2       Inicial                    89                CUC
#
#    COD_REGION_PROCEDENCIA  REGION_PROCEDENCIA  NUM__DECLA_EXPORTACION_ANT  \
# 0                      54  NORTE DE SANTANDER                           0
# 1                      54  NORTE DE SANTANDER                           0
# 2                      54  NORTE DE SANTANDER                           0
#
#    FECH_DECLA_EXPORTACION_ANT  NUM_DECLARACION_PRECEDENTE  \
# 0                           0                           0
# 1                           0                           0
# 2                           0                           0
#
#    FECH_DECLA_PRECEDENTE COD_MODALIDAD_PRECEDENTE COD_MONEDA_TRANSACCION  \
# 0                      0                      NaN                    USD
# 1                      0                      NaN                    USD
# 2                      0                      NaN                    USD
#
#    COD_MODO_TRANSPORTE        MODO_TRANSPORTE  BANDERA  \
# 0                    3  Terrestre (carretero)       13
# 1                    3  Terrestre (carretero)       13
# 2                    3  Terrestre (carretero)       13
#
#   COD_NACIONALIDAD_BANDERA NACIONALIDAD_BANDERA  COD_REGIMEN_CAN  \
# 0                       AF           AFGANISTÁN                1
# 1                       AF           AFGANISTÁN                1
# 2                       AF           AFGANISTÁN                1
#
#    COD_MODALIDAD_EXPORTACION  \
# 0                        198
# 1                        198
# 2                        198
#
#                                MODALIDAD_EXPORTACION  FORMA_PAGO  \
# 0  Exportación definitiva de mercancías de fabric...           1
# 1  Exportación definitiva de mercancías de fabric...           1
# 2  Exportación definitiva de mercancías de fabric...           1
#
#    COD_TIPO_EMBARQUE TIPO_DE_EMBARQUE  COD_TIPO_DATOS  \
# 0                  1            Unico               1
# 1                  1            Unico               1
# 2                  1            Unico               1
#
#              TIPO_DE_DATOS  TIPO_CERTIFICADO_ORIGEN SISTEMAS_ESPECIALES  \
# 0  Definitivos al embarque                        8                  NO
# 1  Definitivos al embarque                        8                  NO
# 2  Definitivos al embarque                        8                  NO
#
#   COD_EXPORTACION_TRANSITO EXPORTACION_EN_TRANSITO  SUBPARTIDA  \
# 0                        N                      NO  8212102000
# 1                        N                      NO  3401300000
# 2                        N                      NO  3809910000
#
#    COD_REGION_ORIGEN    REGION_DE_ORIGEN  COD_UNIDAD_FISICA_NUM  \
# 0                 54  NORTE DE SANTANDER                     11
# 1                 54  NORTE DE SANTANDER                     33
# 2                 54  NORTE DE SANTANDER                     33
#
#   COD_UNIDAD_FISICA_ALF         UNIDAD_FISICA  CANTIDAD_UNIDADES_FISICAS  \
# 0                     U  Unidades o artículos                      74.00
# 1                    KG             Kilogramo                     515.00
# 2                    KG             Kilogramo                   1,056.00
#
#    PESO_BRUTO_KGS  PESO_NETO_KGS  VALOR_FOB_USD  VALOR_FOB_PESOS  \
# 0        3,509.35       3,498.00       5,476.00    21,983,730.56
# 1          516.67         515.00         780.00     3,131,356.80
# 2        1,059.42       1,056.00       1,600.00     6,423,296.00
#
#    VLR_SERIE_AGREGADO_NAL_USD  VALOR_SERIE_FLETES_USD  \
# 0                        0.00                    0.00
# 1                        0.00                    0.00
# 2                        0.00                    0.00
#
#    VALOR_SERIE_SEGUROS_USD  VLR_SERIE_OTROS_GASTOS_USD  COD_ADUANA_SALIDA  \
# 0                     0.00                        0.00                 89
# 1                     0.00                        0.00                 89
# 2                     0.00                        0.00                 89
#
#        ADUANA_SALIDA  FECHA_SOLICITUD_AUTO_EMBARQUE  NUMERO_FORMULARIO  \
# 0  Aduanas de Cúcuta                         202407      6007739047723
# 1  Aduanas de Cúcuta                         202407      6007739047723
# 2  Aduanas de Cúcuta                         202407      6007739047723
#
#    FECHA_DECLARACION_EXPORTACION RAZON_SOCIAL_EXPORTADOR  \
# 0                       20240729      C.I. FERGUTECH SAS
# 1                       20240729      C.I. FERGUTECH SAS
# 2                       20240729      C.I. FERGUTECH SAS
#
#        DIREC_EXPORTADOR  NIT_DECLARANTE RAZON_SOCIAL_DECLARANTE  \
# 0  BG E 2   3 ZN FRANCA  901,557,278.00           BERZATEX SAS.
# 1  BG E 2   3 ZN FRANCA  901,557,278.00           BERZATEX SAS.
# 2  BG E 2   3 ZN FRANCA  901,557,278.00           BERZATEX SAS.
#
#                        RAZON_SOCIAL_DESTINATARIO  \
# 0  COMERCIALIZADORA Y DISTRIBUIDORA LA CHINA C.A
# 1  COMERCIALIZADORA Y DISTRIBUIDORA LA CHINA C.A
# 2  COMERCIALIZADORA Y DISTRIBUIDORA LA CHINA C.A
#
#                        DOMICILIO_DESTINATARIO
# 0  AV BOLIVAR LC NO S/N ZONA ENTRE AV 16 Y 18
# 1  AV BOLIVAR LC NO S/N ZONA ENTRE AV 16 Y 18
# 2  AV BOLIVAR LC NO S/N ZONA ENTRE AV 16 Y 18

# %%
df_expo_ago = pd.read_excel('expo_bienes_2024/08_Exportaciones_2024_Agosto.xlsx')
df_expo_ago.head(3)
# Out:
#    FECHA_PROCESO  NUMERO_SERIE  OFICINA  COD_ADUANA_DESPACHO  \
# 0         202408             4       99                   89
# 1         202408             2       99                   89
# 2         202408             3       99                   89
#
#      ADUANA_DESPACHO  TIPO_IDENT  NIT_EXPORTADOR  TIPO_USUARIO  COD_USUARIO  \
# 0  Aduanas de Cúcuta           2  860,016,695.00            36            0
# 1  Aduanas de Cúcuta           2  860,016,695.00            36            0
# 2  Aduanas de Cúcuta           2  860,016,695.00            36            0
#
#    CLASE_EXPORTADOR  COD_DPTO_EXPORTADOR  COD_PAIS_DESTINO_NUM  \
# 0                 2                11001                   850
# 1                 2                11001                   850
# 2                 2                11001                   850
#
#   COD_PAIS_DESTINO_ALF COD_PAIS_DESTINO                    PAIS_DESTINO_FINAL  \
# 0                  VEN               VE  VENEZUELA (REPÚBLICA BOLIVARIANA DE)
# 1                  VEN               VE  VENEZUELA (REPÚBLICA BOLIVARIANA DE)
# 2                  VEN               VE  VENEZUELA (REPÚBLICA BOLIVARIANA DE)
#
#   CIUDAD_DESTINATARIO  NUM_SOLICITUD_AUTO_EMBARQUE  TIPO_DECLARACION  \
# 0        BARQUISIMETO         6,027,732,667,512.00                 1
# 1        BARQUISIMETO         6,027,732,667,512.00                 1
# 2        BARQUISIMETO         6,027,732,667,512.00                 1
#
#   TIPO_DESPACHO  COD_LUGAR_SALIDA_NUM COD_LUG_SALIDA_ALF  \
# 0       Inicial                    89                CUC
# 1       Inicial                    89                CUC
# 2       Inicial                    89                CUC
#
#    COD_REGION_PROCEDENCIA REGION_PROCEDENCIA  NUM__DECLA_EXPORTACION_ANT  \
# 0                      11          BOGOTA DC                           0
# 1                      11          BOGOTA DC                           0
# 2                      11          BOGOTA DC                           0
#
#    FECH_DECLA_EXPORTACION_ANT  NUM_DECLARACION_PRECEDENTE  \
# 0                           0                           0
# 1                           0                           0
# 2                           0                           0
#
#    FECH_DECLA_PRECEDENTE COD_MODALIDAD_PRECEDENTE COD_MONEDA_TRANSACCION  \
# 0                      0                      NaN                    USD
# 1                      0                      NaN                    USD
# 2                      0                      NaN                    USD
#
#    COD_MODO_TRANSPORTE        MODO_TRANSPORTE  BANDERA  \
# 0                    3  Terrestre (carretero)       13
# 1                    3  Terrestre (carretero)       13
# 2                    3  Terrestre (carretero)       13
#
#   COD_NACIONALIDAD_BANDERA NACIONALIDAD_BANDERA  COD_REGIMEN_CAN  \
# 0                       AF           AFGANISTÁN                1
# 1                       AF           AFGANISTÁN                1
# 2                       AF           AFGANISTÁN                1
#
#    COD_MODALIDAD_EXPORTACION  \
# 0                        198
# 1                        198
# 2                        198
#
#                                MODALIDAD_EXPORTACION  FORMA_PAGO  \
# 0  Exportación definitiva de mercancías de fabric...           1
# 1  Exportación definitiva de mercancías de fabric...           1
# 2  Exportación definitiva de mercancías de fabric...           1
#
#    COD_TIPO_EMBARQUE TIPO_DE_EMBARQUE  COD_TIPO_DATOS  \
# 0                  1            Unico               1
# 1                  1            Unico               1
# 2                  1            Unico               1
#
#              TIPO_DE_DATOS  TIPO_CERTIFICADO_ORIGEN SISTEMAS_ESPECIALES  \
# 0  Definitivos al embarque                        8                  NO
# 1  Definitivos al embarque                        8                  NO
# 2  Definitivos al embarque                        8                  NO
#
#   COD_EXPORTACION_TRANSITO EXPORTACION_EN_TRANSITO  SUBPARTIDA  \
# 0                        N                      NO  3405300000
# 1                        N                      NO  3208900000
# 2                        N                      NO  3208100000
#
#    COD_REGION_ORIGEN REGION_DE_ORIGEN  COD_UNIDAD_FISICA_NUM  \
# 0                 11        BOGOTA DC                     33
# 1                 11        BOGOTA DC                     33
# 2                 11        BOGOTA DC                     33
#
#   COD_UNIDAD_FISICA_ALF UNIDAD_FISICA  CANTIDAD_UNIDADES_FISICAS  \
# 0                    KG     Kilogramo                      76.57
# 1                    KG     Kilogramo                   4,578.92
# 2                    KG     Kilogramo                   3,859.15
#
#    PESO_BRUTO_KGS  PESO_NETO_KGS  VALOR_FOB_USD  VALOR_FOB_PESOS  \
# 0           83.12          76.57          88.40       358,651.17
# 1        4,970.90       4,578.92      10,773.70    43,710,409.21
# 2        4,189.52       3,859.15       5,291.02    21,466,408.88
#
#    VLR_SERIE_AGREGADO_NAL_USD  VALOR_SERIE_FLETES_USD  \
# 0                        0.00                    0.00
# 1                        0.00                    0.00
# 2                        0.00                    0.00
#
#    VALOR_SERIE_SEGUROS_USD  VLR_SERIE_OTROS_GASTOS_USD  COD_ADUANA_SALIDA  \
# 0                     0.00                        0.00                 89
# 1                     0.00                        0.00                 89
# 2                     0.00                        0.00                 89
#
#        ADUANA_SALIDA  FECHA_SOLICITUD_AUTO_EMBARQUE  NUMERO_FORMULARIO  \
# 0  Aduanas de Cúcuta                         202407      6007739046259
# 1  Aduanas de Cúcuta                         202407      6007739046259
# 2  Aduanas de Cúcuta                         202407      6007739046259
#
#    FECHA_DECLARACION_EXPORTACION RAZON_SOCIAL_EXPORTADOR  \
# 0                       20240802           PHILAAC   SAS
# 1                       20240802           PHILAAC   SAS
# 2                       20240802           PHILAAC   SAS
#
#         DIREC_EXPORTADOR  NIT_DECLARANTE  \
# 0  AC 24   95   12 BG 16  860,066,749.00
# 1  AC 24   95   12 BG 16  860,066,749.00
# 2  AC 24   95   12 BG 16  860,066,749.00
#
#                              RAZON_SOCIAL_DECLARANTE  \
# 0  AGENCIA  DE  ADUANAS   ADUANAMIENTOS  LTDA  NI...
# 1  AGENCIA  DE  ADUANAS   ADUANAMIENTOS  LTDA  NI...
# 2  AGENCIA  DE  ADUANAS   ADUANAMIENTOS  LTDA  NI...
#
#   RAZON_SOCIAL_DESTINATARIO                             DOMICILIO_DESTINATARIO
# 0             DISPINZAGO CA  AV LAS INDUSTRIAS ENTRE CLL EN PROYECTO Y CLL ...
# 1             DISPINZAGO CA  AV LAS INDUSTRIAS ENTRE CLL EN PROYECTO Y CLL ...
# 2             DISPINZAGO CA  AV LAS INDUSTRIAS ENTRE CLL EN PROYECTO Y CLL ...

# %%
df_expo_jul.shape
# Out:
# (5427, 72)

# %%
df_expo_ago.shape
# Out:
# (7557, 72)

# %%
# Para concatenar un dataframe debajo del otro (axis=0)
df_expo_2024 = pd.concat([df_expo_jul, df_expo_ago], axis = 0, ignore_index=True)
df_expo_2024.head(3)
# Out:
#    FECHA_PROCESO  NUMERO_SERIE  OFICINA  COD_ADUANA_DESPACHO  \
# 0         202407             7       99                   89
# 1         202407             6       99                   89
# 2         202407             5       99                   89
#
#      ADUANA_DESPACHO  TIPO_IDENT  NIT_EXPORTADOR  TIPO_USUARIO  COD_USUARIO  \
# 0  Aduanas de Cúcuta           2  901,333,018.00            36            0
# 1  Aduanas de Cúcuta           2  901,333,018.00            36            0
# 2  Aduanas de Cúcuta           2  901,333,018.00            36            0
#
#    CLASE_EXPORTADOR  COD_DPTO_EXPORTADOR  COD_PAIS_DESTINO_NUM  \
# 0                 2                54001                   850
# 1                 2                54001                   850
# 2                 2                54001                   850
#
#   COD_PAIS_DESTINO_ALF COD_PAIS_DESTINO                    PAIS_DESTINO_FINAL  \
# 0                  VEN               VE  VENEZUELA (REPÚBLICA BOLIVARIANA DE)
# 1                  VEN               VE  VENEZUELA (REPÚBLICA BOLIVARIANA DE)
# 2                  VEN               VE  VENEZUELA (REPÚBLICA BOLIVARIANA DE)
#
#   CIUDAD_DESTINATARIO  NUM_SOLICITUD_AUTO_EMBARQUE  TIPO_DECLARACION  \
# 0              MERIDA         6,027,733,007,951.00                 1
# 1              MERIDA         6,027,733,007,951.00                 1
# 2              MERIDA         6,027,733,007,951.00                 1
#
#   TIPO_DESPACHO  COD_LUGAR_SALIDA_NUM COD_LUG_SALIDA_ALF  \
# 0       Inicial                    89                CUC
# 1       Inicial                    89                CUC
# 2       Inicial                    89                CUC
#
#    COD_REGION_PROCEDENCIA  REGION_PROCEDENCIA  NUM__DECLA_EXPORTACION_ANT  \
# 0                      54  NORTE DE SANTANDER                           0
# 1                      54  NORTE DE SANTANDER                           0
# 2                      54  NORTE DE SANTANDER                           0
#
#    FECH_DECLA_EXPORTACION_ANT  NUM_DECLARACION_PRECEDENTE  \
# 0                           0                           0
# 1                           0                           0
# 2                           0                           0
#
#    FECH_DECLA_PRECEDENTE COD_MODALIDAD_PRECEDENTE COD_MONEDA_TRANSACCION  \
# 0                      0                      NaN                    USD
# 1                      0                      NaN                    USD
# 2                      0                      NaN                    USD
#
#    COD_MODO_TRANSPORTE        MODO_TRANSPORTE  BANDERA  \
# 0                    3  Terrestre (carretero)       13
# 1                    3  Terrestre (carretero)       13
# 2                    3  Terrestre (carretero)       13
#
#   COD_NACIONALIDAD_BANDERA NACIONALIDAD_BANDERA  COD_REGIMEN_CAN  \
# 0                       AF           AFGANISTÁN                1
# 1                       AF           AFGANISTÁN                1
# 2                       AF           AFGANISTÁN                1
#
#    COD_MODALIDAD_EXPORTACION  \
# 0                        198
# 1                        198
# 2                        198
#
#                                MODALIDAD_EXPORTACION  FORMA_PAGO  \
# 0  Exportación definitiva de mercancías de fabric...           1
# 1  Exportación definitiva de mercancías de fabric...           1
# 2  Exportación definitiva de mercancías de fabric...           1
#
#    COD_TIPO_EMBARQUE TIPO_DE_EMBARQUE  COD_TIPO_DATOS  \
# 0                  1            Unico               1
# 1                  1            Unico               1
# 2                  1            Unico               1
#
#              TIPO_DE_DATOS  TIPO_CERTIFICADO_ORIGEN SISTEMAS_ESPECIALES  \
# 0  Definitivos al embarque                        8                  NO
# 1  Definitivos al embarque                        8                  NO
# 2  Definitivos al embarque                        8                  NO
#
#   COD_EXPORTACION_TRANSITO EXPORTACION_EN_TRANSITO  SUBPARTIDA  \
# 0                        N                      NO  8212102000
# 1                        N                      NO  3401300000
# 2                        N                      NO  3809910000
#
#    COD_REGION_ORIGEN    REGION_DE_ORIGEN  COD_UNIDAD_FISICA_NUM  \
# 0                 54  NORTE DE SANTANDER                     11
# 1                 54  NORTE DE SANTANDER                     33
# 2                 54  NORTE DE SANTANDER                     33
#
#   COD_UNIDAD_FISICA_ALF         UNIDAD_FISICA  CANTIDAD_UNIDADES_FISICAS  \
# 0                     U  Unidades o artículos                      74.00
# 1                    KG             Kilogramo                     515.00
# 2                    KG             Kilogramo                   1,056.00
#
#    PESO_BRUTO_KGS  PESO_NETO_KGS  VALOR_FOB_USD  VALOR_FOB_PESOS  \
# 0        3,509.35       3,498.00       5,476.00    21,983,730.56
# 1          516.67         515.00         780.00     3,131,356.80
# 2        1,059.42       1,056.00       1,600.00     6,423,296.00
#
#    VLR_SERIE_AGREGADO_NAL_USD  VALOR_SERIE_FLETES_USD  \
# 0                        0.00                    0.00
# 1                        0.00                    0.00
# 2                        0.00                    0.00
#
#    VALOR_SERIE_SEGUROS_USD  VLR_SERIE_OTROS_GASTOS_USD  COD_ADUANA_SALIDA  \
# 0                     0.00                        0.00                 89
# 1                     0.00                        0.00                 89
# 2                     0.00                        0.00                 89
#
#        ADUANA_SALIDA  FECHA_SOLICITUD_AUTO_EMBARQUE  NUMERO_FORMULARIO  \
# 0  Aduanas de Cúcuta                         202407      6007739047723
# 1  Aduanas de Cúcuta                         202407      6007739047723
# 2  Aduanas de Cúcuta                         202407      6007739047723
#
#    FECHA_DECLARACION_EXPORTACION RAZON_SOCIAL_EXPORTADOR  \
# 0                       20240729      C.I. FERGUTECH SAS
# 1                       20240729      C.I. FERGUTECH SAS
# 2                       20240729      C.I. FERGUTECH SAS
#
#        DIREC_EXPORTADOR  NIT_DECLARANTE RAZON_SOCIAL_DECLARANTE  \
# 0  BG E 2   3 ZN FRANCA  901,557,278.00           BERZATEX SAS.
# 1  BG E 2   3 ZN FRANCA  901,557,278.00           BERZATEX SAS.
# 2  BG E 2   3 ZN FRANCA  901,557,278.00           BERZATEX SAS.
#
#                        RAZON_SOCIAL_DESTINATARIO  \
# 0  COMERCIALIZADORA Y DISTRIBUIDORA LA CHINA C.A
# 1  COMERCIALIZADORA Y DISTRIBUIDORA LA CHINA C.A
# 2  COMERCIALIZADORA Y DISTRIBUIDORA LA CHINA C.A
#
#                        DOMICILIO_DESTINATARIO
# 0  AV BOLIVAR LC NO S/N ZONA ENTRE AV 16 Y 18
# 1  AV BOLIVAR LC NO S/N ZONA ENTRE AV 16 Y 18
# 2  AV BOLIVAR LC NO S/N ZONA ENTRE AV 16 Y 18

# %%
df_expo_2024.tail(3)
# Out:
#        FECHA_PROCESO  NUMERO_SERIE  OFICINA  COD_ADUANA_DESPACHO  \
# 12981         202408             1       99                   39
# 12982         202408             1       99                   39
# 12983         202408             1       99                   39
#
#                      ADUANA_DESPACHO  TIPO_IDENT  NIT_EXPORTADOR  \
# 12981  Impuestos y Aduanas de Maicao           2  900,797,309.00
# 12982  Impuestos y Aduanas de Maicao           2  901,541,071.00
# 12983  Impuestos y Aduanas de Maicao           2  830,070,950.00
#
#        TIPO_USUARIO  COD_USUARIO  CLASE_EXPORTADOR  COD_DPTO_EXPORTADOR  \
# 12981            36            0                 2                13001
# 12982            36            0                 2                 8001
# 12983            36            0                 2                 5001
#
#        COD_PAIS_DESTINO_NUM COD_PAIS_DESTINO_ALF COD_PAIS_DESTINO  \
# 12981                   850                  VEN               VE
# 12982                   850                  VEN               VE
# 12983                   850                  VEN               VE
#
#                          PAIS_DESTINO_FINAL CIUDAD_DESTINATARIO  \
# 12981  VENEZUELA (REPÚBLICA BOLIVARIANA DE)             CARACAS
# 12982  VENEZUELA (REPÚBLICA BOLIVARIANA DE)             CARACAS
# 12983  VENEZUELA (REPÚBLICA BOLIVARIANA DE)             MATURIN
#
#        NUM_SOLICITUD_AUTO_EMBARQUE  TIPO_DECLARACION TIPO_DESPACHO  \
# 12981         6,027,733,116,785.00                 1       Inicial
# 12982         6,027,734,345,169.00                 1       Inicial
# 12983         6,027,733,628,765.00                 1       Inicial
#
#        COD_LUGAR_SALIDA_NUM COD_LUG_SALIDA_ALF  COD_REGION_PROCEDENCIA  \
# 12981                    39                MAI                      13
# 12982                    39                MAI                      13
# 12983                    39                MAI                      13
#
#       REGION_PROCEDENCIA  NUM__DECLA_EXPORTACION_ANT  \
# 12981            BOLIVAR                           0
# 12982            BOLIVAR                           0
# 12983            BOLIVAR                           0
#
#        FECH_DECLA_EXPORTACION_ANT  NUM_DECLARACION_PRECEDENTE  \
# 12981                           0                           0
# 12982                           0                           0
# 12983                           0                           0
#
#        FECH_DECLA_PRECEDENTE COD_MODALIDAD_PRECEDENTE COD_MONEDA_TRANSACCION  \
# 12981                      0                      NaN                    USD
# 12982                      0                      NaN                    USD
# 12983                      0                      NaN                    USD
#
#        COD_MODO_TRANSPORTE        MODO_TRANSPORTE  BANDERA  \
# 12981                    3  Terrestre (carretero)      169
# 12982                    3  Terrestre (carretero)      169
# 12983                    3  Terrestre (carretero)      169
#
#       COD_NACIONALIDAD_BANDERA NACIONALIDAD_BANDERA  COD_REGIMEN_CAN  \
# 12981                       CO             COLOMBIA                1
# 12982                       CO             COLOMBIA                1
# 12983                       CO             COLOMBIA                1
#
#        COD_MODALIDAD_EXPORTACION  \
# 12981                        198
# 12982                        198
# 12983                        198
#
#                                    MODALIDAD_EXPORTACION  FORMA_PAGO  \
# 12981  Exportación definitiva de mercancías de fabric...           1
# 12982  Exportación definitiva de mercancías de fabric...           1
# 12983  Exportación definitiva de mercancías de fabric...           1
#
#        COD_TIPO_EMBARQUE TIPO_DE_EMBARQUE  COD_TIPO_DATOS  \
# 12981                  1            Unico               1
# 12982                  1            Unico               1
# 12983                  1            Unico               1
#
#                  TIPO_DE_DATOS  TIPO_CERTIFICADO_ORIGEN SISTEMAS_ESPECIALES  \
# 12981  Definitivos al embarque                        8                  NO
# 12982  Definitivos al embarque                        8                  NO
# 12983  Definitivos al embarque                        8                  NO
#
#       COD_EXPORTACION_TRANSITO EXPORTACION_EN_TRANSITO  SUBPARTIDA  \
# 12981                        N                      NO  6809110000
# 12982                        N                      NO  6809110000
# 12983                        N                      NO  2909430000
#
#        COD_REGION_ORIGEN REGION_DE_ORIGEN  COD_UNIDAD_FISICA_NUM  \
# 12981                 13          BOLIVAR                     82
# 12982                 13          BOLIVAR                     82
# 12983                 13          BOLIVAR                     33
#
#       COD_UNIDAD_FISICA_ALF   UNIDAD_FISICA  CANTIDAD_UNIDADES_FISICAS  \
# 12981                    M2  Metro cuadrado                  30,657.36
# 12982                    M2  Metro cuadrado                  40,246.34
# 12983                    KG       Kilogramo                  29,760.00
#
#        PESO_BRUTO_KGS  PESO_NETO_KGS  VALOR_FOB_USD  VALOR_FOB_PESOS  \
# 12981       30,793.61      30,657.36      11,744.12    47,728,456.00
# 12982      267,228.00     261,384.00      85,612.64   345,063,457.77
# 12983       29,760.00      29,760.00      52,587.38   210,947,438.51
#
#        VLR_SERIE_AGREGADO_NAL_USD  VALOR_SERIE_FLETES_USD  \
# 12981                        0.00                    0.00
# 12982                        0.00                    0.00
# 12983                        0.00                4,849.42
#
#        VALOR_SERIE_SEGUROS_USD  VLR_SERIE_OTROS_GASTOS_USD  COD_ADUANA_SALIDA  \
# 12981                     0.00                        0.00                 39
# 12982                     0.00                        0.00                 39
# 12983                     0.00                        0.00                 39
#
#                        ADUANA_SALIDA  FECHA_SOLICITUD_AUTO_EMBARQUE  \
# 12981  Impuestos y Aduanas de Maicao                         202408
# 12982  Impuestos y Aduanas de Maicao                         202408
# 12983  Impuestos y Aduanas de Maicao                         202408
#
#        NUMERO_FORMULARIO  FECHA_DECLARACION_EXPORTACION  \
# 12981      6007739427431                       20240823
# 12982      6007740519871                       20240824
# 12983      6007740250561                       20240821
#
#                             RAZON_SOCIAL_EXPORTADOR  \
# 12981                    KNAUF DISTRIBUIDORA S.A.S.
# 12982  COMERCIALIZADORA INTERNACIONAL PROARCA S.A.S
# 12983                               C I CONALEX SAS
#
#                                         DIREC_EXPORTADOR  NIT_DECLARANTE  \
# 12981  BRR BOSQUE TV  54   21 A   120     CENTRO EMPR...  890,403,077.00
# 12982  CR 53   106   280 OF 8 A P 8 TO B  CENTRO EMPR...  800,227,414.00
# 12983                       CR 43 A   1 A  SUR 69 IN 703  811,001,259.00
#
#                          RAZON_SOCIAL_DECLARANTE  \
# 12981  AGENCIA DE ADUANAS HUBEMAR S.A.S  NIVEL 1
# 12982     AGENCIA DE ADUANAS MERCO S.A.S NIVEL 1
# 12983    AGENCIA DE ADUANAS ROLDAN S.A.S NIVEL 1
#
#                      RAZON_SOCIAL_DESTINATARIO  \
# 12981          RAPIDFIX COMERCIALIZADORA, C.A.
# 12982  PRODUCTOS ARQUITECTONICOS PROARCA C. A.
# 12983                  PETRO SERVICES GSM, C.A
#
#                                   DOMICILIO_DESTINATARIO
# 12981                    CALLE LOS ANGELES LC GALPON N35
# 12982  AV. MILAN CON CALLE BOSTON LOCAL PARCELA 1028 ...
# 12983         AV MONTERREY CC SERVIMAS MONTERREY NIVEL 1

# %%
df_expo_2024.shape
# Out:
# (12984, 72)

# %%
# Para concatenar un dataframe al lado del otro, se coloca axis = 1
df_expo_2024_hor = pd.concat([df_expo_jul, df_expo_ago], axis = 1)
df_expo_2024_hor.head(3)
# Out:
#    FECHA_PROCESO  NUMERO_SERIE  OFICINA  COD_ADUANA_DESPACHO  \
# 0     202,407.00          7.00    99.00                89.00
# 1     202,407.00          6.00    99.00                89.00
# 2     202,407.00          5.00    99.00                89.00
#
#      ADUANA_DESPACHO  TIPO_IDENT  NIT_EXPORTADOR  TIPO_USUARIO  COD_USUARIO  \
# 0  Aduanas de Cúcuta        2.00  901,333,018.00         36.00         0.00
# 1  Aduanas de Cúcuta        2.00  901,333,018.00         36.00         0.00
# 2  Aduanas de Cúcuta        2.00  901,333,018.00         36.00         0.00
#
#    CLASE_EXPORTADOR  COD_DPTO_EXPORTADOR  COD_PAIS_DESTINO_NUM  \
# 0              2.00            54,001.00                850.00
# 1              2.00            54,001.00                850.00
# 2              2.00            54,001.00                850.00
#
#   COD_PAIS_DESTINO_ALF COD_PAIS_DESTINO                    PAIS_DESTINO_FINAL  \
# 0                  VEN               VE  VENEZUELA (REPÚBLICA BOLIVARIANA DE)
# 1                  VEN               VE  VENEZUELA (REPÚBLICA BOLIVARIANA DE)
# 2                  VEN               VE  VENEZUELA (REPÚBLICA BOLIVARIANA DE)
#
#   CIUDAD_DESTINATARIO  NUM_SOLICITUD_AUTO_EMBARQUE  TIPO_DECLARACION  \
# 0              MERIDA         6,027,733,007,951.00              1.00
# 1              MERIDA         6,027,733,007,951.00              1.00
# 2              MERIDA         6,027,733,007,951.00              1.00
#
#   TIPO_DESPACHO  COD_LUGAR_SALIDA_NUM COD_LUG_SALIDA_ALF  \
# 0       Inicial                 89.00                CUC
# 1       Inicial                 89.00                CUC
# 2       Inicial                 89.00                CUC
#
#    COD_REGION_PROCEDENCIA  REGION_PROCEDENCIA  NUM__DECLA_EXPORTACION_ANT  \
# 0                   54.00  NORTE DE SANTANDER                        0.00
# 1                   54.00  NORTE DE SANTANDER                        0.00
# 2                   54.00  NORTE DE SANTANDER                        0.00
#
#    FECH_DECLA_EXPORTACION_ANT  NUM_DECLARACION_PRECEDENTE  \
# 0                        0.00                        0.00
# 1                        0.00                        0.00
# 2                        0.00                        0.00
#
#    FECH_DECLA_PRECEDENTE COD_MODALIDAD_PRECEDENTE COD_MONEDA_TRANSACCION  \
# 0                   0.00                      NaN                    USD
# 1                   0.00                      NaN                    USD
# 2                   0.00                      NaN                    USD
#
#    COD_MODO_TRANSPORTE        MODO_TRANSPORTE  BANDERA  \
# 0                 3.00  Terrestre (carretero)    13.00
# 1                 3.00  Terrestre (carretero)    13.00
# 2                 3.00  Terrestre (carretero)    13.00
#
#   COD_NACIONALIDAD_BANDERA NACIONALIDAD_BANDERA  COD_REGIMEN_CAN  \
# 0                       AF           AFGANISTÁN             1.00
# 1                       AF           AFGANISTÁN             1.00
# 2                       AF           AFGANISTÁN             1.00
#
#    COD_MODALIDAD_EXPORTACION  \
# 0                     198.00
# 1                     198.00
# 2                     198.00
#
#                                MODALIDAD_EXPORTACION  FORMA_PAGO  \
# 0  Exportación definitiva de mercancías de fabric...        1.00
# 1  Exportación definitiva de mercancías de fabric...        1.00
# 2  Exportación definitiva de mercancías de fabric...        1.00
#
#    COD_TIPO_EMBARQUE TIPO_DE_EMBARQUE  COD_TIPO_DATOS  \
# 0               1.00            Unico            1.00
# 1               1.00            Unico            1.00
# 2               1.00            Unico            1.00
#
#              TIPO_DE_DATOS  TIPO_CERTIFICADO_ORIGEN SISTEMAS_ESPECIALES  \
# 0  Definitivos al embarque                     8.00                  NO
# 1  Definitivos al embarque                     8.00                  NO
# 2  Definitivos al embarque                     8.00                  NO
#
#   COD_EXPORTACION_TRANSITO EXPORTACION_EN_TRANSITO       SUBPARTIDA  \
# 0                        N                      NO 8,212,102,000.00
# 1                        N                      NO 3,401,300,000.00
# 2                        N                      NO 3,809,910,000.00
#
#    COD_REGION_ORIGEN    REGION_DE_ORIGEN  COD_UNIDAD_FISICA_NUM  \
# 0              54.00  NORTE DE SANTANDER                  11.00
# 1              54.00  NORTE DE SANTANDER                  33.00
# 2              54.00  NORTE DE SANTANDER                  33.00
#
#   COD_UNIDAD_FISICA_ALF         UNIDAD_FISICA  CANTIDAD_UNIDADES_FISICAS  \
# 0                     U  Unidades o artículos                      74.00
# 1                    KG             Kilogramo                     515.00
# 2                    KG             Kilogramo                   1,056.00
#
#    PESO_BRUTO_KGS  PESO_NETO_KGS  VALOR_FOB_USD  VALOR_FOB_PESOS  \
# 0        3,509.35       3,498.00       5,476.00    21,983,730.56
# 1          516.67         515.00         780.00     3,131,356.80
# 2        1,059.42       1,056.00       1,600.00     6,423,296.00
#
#    VLR_SERIE_AGREGADO_NAL_USD  VALOR_SERIE_FLETES_USD  \
# 0                        0.00                    0.00
# 1                        0.00                    0.00
# 2                        0.00                    0.00
#
#    VALOR_SERIE_SEGUROS_USD  VLR_SERIE_OTROS_GASTOS_USD  COD_ADUANA_SALIDA  \
# 0                     0.00                        0.00              89.00
# 1                     0.00                        0.00              89.00
# 2                     0.00                        0.00              89.00
#
#        ADUANA_SALIDA  FECHA_SOLICITUD_AUTO_EMBARQUE    NUMERO_FORMULARIO  \
# 0  Aduanas de Cúcuta                     202,407.00 6,007,739,047,723.00
# 1  Aduanas de Cúcuta                     202,407.00 6,007,739,047,723.00
# 2  Aduanas de Cúcuta                     202,407.00 6,007,739,047,723.00
#
#    FECHA_DECLARACION_EXPORTACION RAZON_SOCIAL_EXPORTADOR  \
# 0                  20,240,729.00      C.I. FERGUTECH SAS
# 1                  20,240,729.00      C.I. FERGUTECH SAS
# 2                  20,240,729.00      C.I. FERGUTECH SAS
#
#        DIREC_EXPORTADOR  NIT_DECLARANTE RAZON_SOCIAL_DECLARANTE  \
# 0  BG E 2   3 ZN FRANCA  901,557,278.00           BERZATEX SAS.
# 1  BG E 2   3 ZN FRANCA  901,557,278.00           BERZATEX SAS.
# 2  BG E 2   3 ZN FRANCA  901,557,278.00           BERZATEX SAS.
#
#                        RAZON_SOCIAL_DESTINATARIO  \
# 0  COMERCIALIZADORA Y DISTRIBUIDORA LA CHINA C.A
# 1  COMERCIALIZADORA Y DISTRIBUIDORA LA CHINA C.A
# 2  COMERCIALIZADORA Y DISTRIBUIDORA LA CHINA C.A
#
#                        DOMICILIO_DESTINATARIO  FECHA_PROCESO  NUMERO_SERIE  \
# 0  AV BOLIVAR LC NO S/N ZONA ENTRE AV 16 Y 18         202408             4
# 1  AV BOLIVAR LC NO S/N ZONA ENTRE AV 16 Y 18         202408             2
# 2  AV BOLIVAR LC NO S/N ZONA ENTRE AV 16 Y 18         202408             3
#
#    OFICINA  COD_ADUANA_DESPACHO    ADUANA_DESPACHO  TIPO_IDENT  \
# 0       99                   89  Aduanas de Cúcuta           2
# 1       99                   89  Aduanas de Cúcuta           2
# 2       99                   89  Aduanas de Cúcuta           2
#
#    NIT_EXPORTADOR  TIPO_USUARIO  COD_USUARIO  CLASE_EXPORTADOR  \
# 0  860,016,695.00            36            0                 2
# 1  860,016,695.00            36            0                 2
# 2  860,016,695.00            36            0                 2
#
#    COD_DPTO_EXPORTADOR  COD_PAIS_DESTINO_NUM COD_PAIS_DESTINO_ALF  \
# 0                11001                   850                  VEN
# 1                11001                   850                  VEN
# 2                11001                   850                  VEN
#
#   COD_PAIS_DESTINO                    PAIS_DESTINO_FINAL CIUDAD_DESTINATARIO  \
# 0               VE  VENEZUELA (REPÚBLICA BOLIVARIANA DE)        BARQUISIMETO
# 1               VE  VENEZUELA (REPÚBLICA BOLIVARIANA DE)        BARQUISIMETO
# 2               VE  VENEZUELA (REPÚBLICA BOLIVARIANA DE)        BARQUISIMETO
#
#    NUM_SOLICITUD_AUTO_EMBARQUE  TIPO_DECLARACION TIPO_DESPACHO  \
# 0         6,027,732,667,512.00                 1       Inicial
# 1         6,027,732,667,512.00                 1       Inicial
# 2         6,027,732,667,512.00                 1       Inicial
#
#    COD_LUGAR_SALIDA_NUM COD_LUG_SALIDA_ALF  COD_REGION_PROCEDENCIA  \
# 0                    89                CUC                      11
# 1                    89                CUC                      11
# 2                    89                CUC                      11
#
#   REGION_PROCEDENCIA  NUM__DECLA_EXPORTACION_ANT  FECH_DECLA_EXPORTACION_ANT  \
# 0          BOGOTA DC                           0                           0
# 1          BOGOTA DC                           0                           0
# 2          BOGOTA DC                           0                           0
#
#    NUM_DECLARACION_PRECEDENTE  FECH_DECLA_PRECEDENTE COD_MODALIDAD_PRECEDENTE  \
# 0                           0                      0                      NaN
# 1                           0                      0                      NaN
# 2                           0                      0                      NaN
#
#   COD_MONEDA_TRANSACCION  COD_MODO_TRANSPORTE        MODO_TRANSPORTE  BANDERA  \
# 0                    USD                    3  Terrestre (carretero)       13
# 1                    USD                    3  Terrestre (carretero)       13
# 2                    USD                    3  Terrestre (carretero)       13
#
#   COD_NACIONALIDAD_BANDERA NACIONALIDAD_BANDERA  COD_REGIMEN_CAN  \
# 0                       AF           AFGANISTÁN                1
# 1                       AF           AFGANISTÁN                1
# 2                       AF           AFGANISTÁN                1
#
#    COD_MODALIDAD_EXPORTACION  \
# 0                        198
# 1                        198
# 2                        198
#
#                                MODALIDAD_EXPORTACION  FORMA_PAGO  \
# 0  Exportación definitiva de mercancías de fabric...           1
# 1  Exportación definitiva de mercancías de fabric...           1
# 2  Exportación definitiva de mercancías de fabric...           1
#
#    COD_TIPO_EMBARQUE TIPO_DE_EMBARQUE  COD_TIPO_DATOS  \
# 0                  1            Unico               1
# 1                  1            Unico               1
# 2                  1            Unico               1
#
#              TIPO_DE_DATOS  TIPO_CERTIFICADO_ORIGEN SISTEMAS_ESPECIALES  \
# 0  Definitivos al embarque                        8                  NO
# 1  Definitivos al embarque                        8                  NO
# 2  Definitivos al embarque                        8                  NO
#
#   COD_EXPORTACION_TRANSITO EXPORTACION_EN_TRANSITO  SUBPARTIDA  \
# 0                        N                      NO  3405300000
# 1                        N                      NO  3208900000
# 2                        N                      NO  3208100000
#
#    COD_REGION_ORIGEN REGION_DE_ORIGEN  COD_UNIDAD_FISICA_NUM  \
# 0                 11        BOGOTA DC                     33
# 1                 11        BOGOTA DC                     33
# 2                 11        BOGOTA DC                     33
#
#   COD_UNIDAD_FISICA_ALF UNIDAD_FISICA  CANTIDAD_UNIDADES_FISICAS  \
# 0                    KG     Kilogramo                      76.57
# 1                    KG     Kilogramo                   4,578.92
# 2                    KG     Kilogramo                   3,859.15
#
#    PESO_BRUTO_KGS  PESO_NETO_KGS  VALOR_FOB_USD  VALOR_FOB_PESOS  \
# 0           83.12          76.57          88.40       358,651.17
# 1        4,970.90       4,578.92      10,773.70    43,710,409.21
# 2        4,189.52       3,859.15       5,291.02    21,466,408.88
#
#    VLR_SERIE_AGREGADO_NAL_USD  VALOR_SERIE_FLETES_USD  \
# 0                        0.00                    0.00
# 1                        0.00                    0.00
# 2                        0.00                    0.00
#
#    VALOR_SERIE_SEGUROS_USD  VLR_SERIE_OTROS_GASTOS_USD  COD_ADUANA_SALIDA  \
# 0                     0.00                        0.00                 89
# 1                     0.00                        0.00                 89
# 2                     0.00                        0.00                 89
#
#        ADUANA_SALIDA  FECHA_SOLICITUD_AUTO_EMBARQUE  NUMERO_FORMULARIO  \
# 0  Aduanas de Cúcuta                         202407      6007739046259
# 1  Aduanas de Cúcuta                         202407      6007739046259
# 2  Aduanas de Cúcuta                         202407      6007739046259
#
#    FECHA_DECLARACION_EXPORTACION RAZON_SOCIAL_EXPORTADOR  \
# 0                       20240802           PHILAAC   SAS
# 1                       20240802           PHILAAC   SAS
# 2                       20240802           PHILAAC   SAS
#
#         DIREC_EXPORTADOR  NIT_DECLARANTE  \
# 0  AC 24   95   12 BG 16  860,066,749.00
# 1  AC 24   95   12 BG 16  860,066,749.00
# 2  AC 24   95   12 BG 16  860,066,749.00
#
#                              RAZON_SOCIAL_DECLARANTE  \
# 0  AGENCIA  DE  ADUANAS   ADUANAMIENTOS  LTDA  NI...
# 1  AGENCIA  DE  ADUANAS   ADUANAMIENTOS  LTDA  NI...
# 2  AGENCIA  DE  ADUANAS   ADUANAMIENTOS  LTDA  NI...
#
#   RAZON_SOCIAL_DESTINATARIO                             DOMICILIO_DESTINATARIO
# 0             DISPINZAGO CA  AV LAS INDUSTRIAS ENTRE CLL EN PROYECTO Y CLL ...
# 1             DISPINZAGO CA  AV LAS INDUSTRIAS ENTRE CLL EN PROYECTO Y CLL ...
# 2             DISPINZAGO CA  AV LAS INDUSTRIAS ENTRE CLL EN PROYECTO Y CLL ...

# %%
df_expo_2024_hor.shape
# Out:
# (7557, 144)

# %%
df_expo_2024_hor.tail(3)
# Out:
#       FECHA_PROCESO  NUMERO_SERIE  OFICINA  COD_ADUANA_DESPACHO  \
# 7554            NaN           NaN      NaN                  NaN
# 7555            NaN           NaN      NaN                  NaN
# 7556            NaN           NaN      NaN                  NaN
#
#      ADUANA_DESPACHO  TIPO_IDENT  NIT_EXPORTADOR  TIPO_USUARIO  COD_USUARIO  \
# 7554             NaN         NaN             NaN           NaN          NaN
# 7555             NaN         NaN             NaN           NaN          NaN
# 7556             NaN         NaN             NaN           NaN          NaN
#
#       CLASE_EXPORTADOR  COD_DPTO_EXPORTADOR  COD_PAIS_DESTINO_NUM  \
# 7554               NaN                  NaN                   NaN
# 7555               NaN                  NaN                   NaN
# 7556               NaN                  NaN                   NaN
#
#      COD_PAIS_DESTINO_ALF COD_PAIS_DESTINO PAIS_DESTINO_FINAL  \
# 7554                  NaN              NaN                NaN
# 7555                  NaN              NaN                NaN
# 7556                  NaN              NaN                NaN
#
#      CIUDAD_DESTINATARIO  NUM_SOLICITUD_AUTO_EMBARQUE  TIPO_DECLARACION  \
# 7554                 NaN                          NaN               NaN
# 7555                 NaN                          NaN               NaN
# 7556                 NaN                          NaN               NaN
#
#      TIPO_DESPACHO  COD_LUGAR_SALIDA_NUM COD_LUG_SALIDA_ALF  \
# 7554           NaN                   NaN                NaN
# 7555           NaN                   NaN                NaN
# 7556           NaN                   NaN                NaN
#
#       COD_REGION_PROCEDENCIA REGION_PROCEDENCIA  NUM__DECLA_EXPORTACION_ANT  \
# 7554                     NaN                NaN                         NaN
# 7555                     NaN                NaN                         NaN
# 7556                     NaN                NaN                         NaN
#
#       FECH_DECLA_EXPORTACION_ANT  NUM_DECLARACION_PRECEDENTE  \
# 7554                         NaN                         NaN
# 7555                         NaN                         NaN
# 7556                         NaN                         NaN
#
#       FECH_DECLA_PRECEDENTE COD_MODALIDAD_PRECEDENTE COD_MONEDA_TRANSACCION  \
# 7554                    NaN                      NaN                    NaN
# 7555                    NaN                      NaN                    NaN
# 7556                    NaN                      NaN                    NaN
#
#       COD_MODO_TRANSPORTE MODO_TRANSPORTE  BANDERA COD_NACIONALIDAD_BANDERA  \
# 7554                  NaN             NaN      NaN                      NaN
# 7555                  NaN             NaN      NaN                      NaN
# 7556                  NaN             NaN      NaN                      NaN
#
#      NACIONALIDAD_BANDERA  COD_REGIMEN_CAN  COD_MODALIDAD_EXPORTACION  \
# 7554                  NaN              NaN                        NaN
# 7555                  NaN              NaN                        NaN
# 7556                  NaN              NaN                        NaN
#
#      MODALIDAD_EXPORTACION  FORMA_PAGO  COD_TIPO_EMBARQUE TIPO_DE_EMBARQUE  \
# 7554                   NaN         NaN                NaN              NaN
# 7555                   NaN         NaN                NaN              NaN
# 7556                   NaN         NaN                NaN              NaN
#
#       COD_TIPO_DATOS TIPO_DE_DATOS  TIPO_CERTIFICADO_ORIGEN  \
# 7554             NaN           NaN                      NaN
# 7555             NaN           NaN                      NaN
# 7556             NaN           NaN                      NaN
#
#      SISTEMAS_ESPECIALES COD_EXPORTACION_TRANSITO EXPORTACION_EN_TRANSITO  \
# 7554                 NaN                      NaN                     NaN
# 7555                 NaN                      NaN                     NaN
# 7556                 NaN                      NaN                     NaN
#
#       SUBPARTIDA  COD_REGION_ORIGEN REGION_DE_ORIGEN  COD_UNIDAD_FISICA_NUM  \
# 7554         NaN                NaN              NaN                    NaN
# 7555         NaN                NaN              NaN                    NaN
# 7556         NaN                NaN              NaN                    NaN
#
#      COD_UNIDAD_FISICA_ALF UNIDAD_FISICA  CANTIDAD_UNIDADES_FISICAS  \
# 7554                   NaN           NaN                        NaN
# 7555                   NaN           NaN                        NaN
# 7556                   NaN           NaN                        NaN
#
#       PESO_BRUTO_KGS  PESO_NETO_KGS  VALOR_FOB_USD  VALOR_FOB_PESOS  \
# 7554             NaN            NaN            NaN              NaN
# 7555             NaN            NaN            NaN              NaN
# 7556             NaN            NaN            NaN              NaN
#
#       VLR_SERIE_AGREGADO_NAL_USD  VALOR_SERIE_FLETES_USD  \
# 7554                         NaN                     NaN
# 7555                         NaN                     NaN
# 7556                         NaN                     NaN
#
#       VALOR_SERIE_SEGUROS_USD  VLR_SERIE_OTROS_GASTOS_USD  COD_ADUANA_SALIDA  \
# 7554                      NaN                         NaN                NaN
# 7555                      NaN                         NaN                NaN
# 7556                      NaN                         NaN                NaN
#
#      ADUANA_SALIDA  FECHA_SOLICITUD_AUTO_EMBARQUE  NUMERO_FORMULARIO  \
# 7554           NaN                            NaN                NaN
# 7555           NaN                            NaN                NaN
# 7556           NaN                            NaN                NaN
#
#       FECHA_DECLARACION_EXPORTACION RAZON_SOCIAL_EXPORTADOR DIREC_EXPORTADOR  \
# 7554                            NaN                     NaN              NaN
# 7555                            NaN                     NaN              NaN
# 7556                            NaN                     NaN              NaN
#
#       NIT_DECLARANTE RAZON_SOCIAL_DECLARANTE RAZON_SOCIAL_DESTINATARIO  \
# 7554             NaN                     NaN                       NaN
# 7555             NaN                     NaN                       NaN
# 7556             NaN                     NaN                       NaN
#
#      DOMICILIO_DESTINATARIO  FECHA_PROCESO  NUMERO_SERIE  OFICINA  \
# 7554                    NaN         202408             1       99
# 7555                    NaN         202408             1       99
# 7556                    NaN         202408             1       99
#
#       COD_ADUANA_DESPACHO                ADUANA_DESPACHO  TIPO_IDENT  \
# 7554                   39  Impuestos y Aduanas de Maicao           2
# 7555                   39  Impuestos y Aduanas de Maicao           2
# 7556                   39  Impuestos y Aduanas de Maicao           2
#
#       NIT_EXPORTADOR  TIPO_USUARIO  COD_USUARIO  CLASE_EXPORTADOR  \
# 7554  900,797,309.00            36            0                 2
# 7555  901,541,071.00            36            0                 2
# 7556  830,070,950.00            36            0                 2
#
#       COD_DPTO_EXPORTADOR  COD_PAIS_DESTINO_NUM COD_PAIS_DESTINO_ALF  \
# 7554                13001                   850                  VEN
# 7555                 8001                   850                  VEN
# 7556                 5001                   850                  VEN
#
#      COD_PAIS_DESTINO                    PAIS_DESTINO_FINAL  \
# 7554               VE  VENEZUELA (REPÚBLICA BOLIVARIANA DE)
# 7555               VE  VENEZUELA (REPÚBLICA BOLIVARIANA DE)
# 7556               VE  VENEZUELA (REPÚBLICA BOLIVARIANA DE)
#
#      CIUDAD_DESTINATARIO  NUM_SOLICITUD_AUTO_EMBARQUE  TIPO_DECLARACION  \
# 7554             CARACAS         6,027,733,116,785.00                 1
# 7555             CARACAS         6,027,734,345,169.00                 1
# 7556             MATURIN         6,027,733,628,765.00                 1
#
#      TIPO_DESPACHO  COD_LUGAR_SALIDA_NUM COD_LUG_SALIDA_ALF  \
# 7554       Inicial                    39                MAI
# 7555       Inicial                    39                MAI
# 7556       Inicial                    39                MAI
#
#       COD_REGION_PROCEDENCIA REGION_PROCEDENCIA  NUM__DECLA_EXPORTACION_ANT  \
# 7554                      13            BOLIVAR                           0
# 7555                      13            BOLIVAR                           0
# 7556                      13            BOLIVAR                           0
#
#       FECH_DECLA_EXPORTACION_ANT  NUM_DECLARACION_PRECEDENTE  \
# 7554                           0                           0
# 7555                           0                           0
# 7556                           0                           0
#
#       FECH_DECLA_PRECEDENTE COD_MODALIDAD_PRECEDENTE COD_MONEDA_TRANSACCION  \
# 7554                      0                      NaN                    USD
# 7555                      0                      NaN                    USD
# 7556                      0                      NaN                    USD
#
#       COD_MODO_TRANSPORTE        MODO_TRANSPORTE  BANDERA  \
# 7554                    3  Terrestre (carretero)      169
# 7555                    3  Terrestre (carretero)      169
# 7556                    3  Terrestre (carretero)      169
#
#      COD_NACIONALIDAD_BANDERA NACIONALIDAD_BANDERA  COD_REGIMEN_CAN  \
# 7554                       CO             COLOMBIA                1
# 7555                       CO             COLOMBIA                1
# 7556                       CO             COLOMBIA                1
#
#       COD_MODALIDAD_EXPORTACION  \
# 7554                        198
# 7555                        198
# 7556                        198
#
#                                   MODALIDAD_EXPORTACION  FORMA_PAGO  \
# 7554  Exportación definitiva de mercancías de fabric...           1
# 7555  Exportación definitiva de mercancías de fabric...           1
# 7556  Exportación definitiva de mercancías de fabric...           1
#
#       COD_TIPO_EMBARQUE TIPO_DE_EMBARQUE  COD_TIPO_DATOS  \
# 7554                  1            Unico               1
# 7555                  1            Unico               1
# 7556                  1            Unico               1
#
#                 TIPO_DE_DATOS  TIPO_CERTIFICADO_ORIGEN SISTEMAS_ESPECIALES  \
# 7554  Definitivos al embarque                        8                  NO
# 7555  Definitivos al embarque                        8                  NO
# 7556  Definitivos al embarque                        8                  NO
#
#      COD_EXPORTACION_TRANSITO EXPORTACION_EN_TRANSITO  SUBPARTIDA  \
# 7554                        N                      NO  6809110000
# 7555                        N                      NO  6809110000
# 7556                        N                      NO  2909430000
#
#       COD_REGION_ORIGEN REGION_DE_ORIGEN  COD_UNIDAD_FISICA_NUM  \
# 7554                 13          BOLIVAR                     82
# 7555                 13          BOLIVAR                     82
# 7556                 13          BOLIVAR                     33
#
#      COD_UNIDAD_FISICA_ALF   UNIDAD_FISICA  CANTIDAD_UNIDADES_FISICAS  \
# 7554                    M2  Metro cuadrado                  30,657.36
# 7555                    M2  Metro cuadrado                  40,246.34
# 7556                    KG       Kilogramo                  29,760.00
#
#       PESO_BRUTO_KGS  PESO_NETO_KGS  VALOR_FOB_USD  VALOR_FOB_PESOS  \
# 7554       30,793.61      30,657.36      11,744.12    47,728,456.00
# 7555      267,228.00     261,384.00      85,612.64   345,063,457.77
# 7556       29,760.00      29,760.00      52,587.38   210,947,438.51
#
#       VLR_SERIE_AGREGADO_NAL_USD  VALOR_SERIE_FLETES_USD  \
# 7554                        0.00                    0.00
# 7555                        0.00                    0.00
# 7556                        0.00                4,849.42
#
#       VALOR_SERIE_SEGUROS_USD  VLR_SERIE_OTROS_GASTOS_USD  COD_ADUANA_SALIDA  \
# 7554                     0.00                        0.00                 39
# 7555                     0.00                        0.00                 39
# 7556                     0.00                        0.00                 39
#
#                       ADUANA_SALIDA  FECHA_SOLICITUD_AUTO_EMBARQUE  \
# 7554  Impuestos y Aduanas de Maicao                         202408
# 7555  Impuestos y Aduanas de Maicao                         202408
# 7556  Impuestos y Aduanas de Maicao                         202408
#
#       NUMERO_FORMULARIO  FECHA_DECLARACION_EXPORTACION  \
# 7554      6007739427431                       20240823
# 7555      6007740519871                       20240824
# 7556      6007740250561                       20240821
#
#                            RAZON_SOCIAL_EXPORTADOR  \
# 7554                    KNAUF DISTRIBUIDORA S.A.S.
# 7555  COMERCIALIZADORA INTERNACIONAL PROARCA S.A.S
# 7556                               C I CONALEX SAS
#
#                                        DIREC_EXPORTADOR  NIT_DECLARANTE  \
# 7554  BRR BOSQUE TV  54   21 A   120     CENTRO EMPR...  890,403,077.00
# 7555  CR 53   106   280 OF 8 A P 8 TO B  CENTRO EMPR...  800,227,414.00
# 7556                       CR 43 A   1 A  SUR 69 IN 703  811,001,259.00
#
#                         RAZON_SOCIAL_DECLARANTE  \
# 7554  AGENCIA DE ADUANAS HUBEMAR S.A.S  NIVEL 1
# 7555     AGENCIA DE ADUANAS MERCO S.A.S NIVEL 1
# 7556    AGENCIA DE ADUANAS ROLDAN S.A.S NIVEL 1
#
#                     RAZON_SOCIAL_DESTINATARIO  \
# 7554          RAPIDFIX COMERCIALIZADORA, C.A.
# 7555  PRODUCTOS ARQUITECTONICOS PROARCA C. A.
# 7556                  PETRO SERVICES GSM, C.A
#
#                                  DOMICILIO_DESTINATARIO
# 7554                    CALLE LOS ANGELES LC GALPON N35
# 7555  AV. MILAN CON CALLE BOSTON LOCAL PARCELA 1028 ...
# 7556         AV MONTERREY CC SERVIMAS MONTERREY NIVEL 1

# %% [markdown]
# ### Cruce de Información con `pd.merge()`
#
# `merge` es una de las operaciones más poderosas. Emula los `JOIN` de SQL y nos permite combinar DataFrames basándose en el valor de una o más columnas en común (llaves o "keys").
#
# **Ejemplo:** El Banco de la República te contrata. Te entregan una tabla con el Indicador de Seguimiento a la Economía (ISE) para cada mes. Por otro lado, la Bolsa de Valores de Colombia te da una tabla con el volumen de negociación del índice COLCAP, también para cada mes. `merge` es la operación de tomar estas dos tablas y, usando la columna "mes" como el punto de conexión, crear una nueva tabla más rica que contenga tanto el ISE como el volumen del COLCAP en la misma fila para cada mes.

# %% [markdown]
# Vamos a explorar los 4 tipos de `merge` más comunes: `inner`, `left`, `right`, y `outer`.
#
# ![Tipos de merge](https://drive.google.com/uc?id=1JQ_QH90nibxiBXoZezP4GgtMFNMp7gzV)

# %%
# Para el ejemplo, vamos a crear dos dataframes

# DataFrame 1: Datos de población por país
df_poblacion = pd.DataFrame({
    'codigo_pais': ['COL', 'MEX', 'PER', 'ECU'],
    'poblacion_millones': [52.1, 128.9, 34.0, 18.0]
})

# DataFrame 2: Datos de Llegada de Inversión Extranjera Directa (IED)
# Nota: No tenemos datos para Ecuador (ECU), pero sí para Argentina (ARG), que no está en el otro DF.
df_ied = pd.DataFrame({
    'iso_code': ['COL', 'MEX', 'PER', 'ARG'],
    'ied_millones_usd': [17048, 35292, 11738, 15055]
})

print("Población:")
display(df_poblacion)
print("IED:")
display(df_ied)
# Out:
# Población:
#   codigo_pais  poblacion_millones
# 0         COL               52.10
# 1         MEX              128.90
# 2         PER               34.00
# 3         ECU               18.00
# IED:
#   iso_code  ied_millones_usd
# 0      COL             17048
# 1      MEX             35292
# 2      PER             11738
# 3      ARG             15055

# %% [markdown]
# #### MERGE TIPO 1: INNER JOIN (Intersección)
#
# Solo nos devuelve las filas donde la llave ('codigo_pais'/'iso_code') existe en AMBOS DataFrames.

# %%
df_inner = pd.merge(df_poblacion, df_ied, left_on='codigo_pais', right_on='iso_code', how='inner')

print("\n--- INNER JOIN ---")
print("Resultado: Solo países presentes en ambos datasets.")
display(df_inner)
# Out:
# --- INNER JOIN ---
# Resultado: Solo países presentes en ambos datasets.
#   codigo_pais  poblacion_millones iso_code  ied_millones_usd
# 0         COL               52.10      COL             17048
# 1         MEX              128.90      MEX             35292
# 2         PER               34.00      PER             11738

# %% [markdown]
# #### MERGE TIPO 2: LEFT JOIN
#
# Mantiene TODAS las filas del DataFrame de la izquierda ('df_poblacion') y trae los datos del de la derecha si la llave coincide. Si no, pone NaN.

# %%
df_left = pd.merge(df_poblacion, df_ied, left_on='codigo_pais', right_on='iso_code', how='left')

print("\n--- LEFT JOIN ---")
print("Resultado: Todos los países de 'población', con datos de IED si están disponibles.")
display(df_left)
# Out:
# --- LEFT JOIN ---
# Resultado: Todos los países de 'población', con datos de IED si están disponibles.
#   codigo_pais  poblacion_millones iso_code  ied_millones_usd
# 0         COL               52.10      COL         17,048.00
# 1         MEX              128.90      MEX         35,292.00
# 2         PER               34.00      PER         11,738.00
# 3         ECU               18.00      NaN               NaN

# %% [markdown]
# #### MERGE TIPO 3: RIGHT JOIN
# Mantiene TODAS las filas del DataFrame de la derecha ('df_ied') y trae los datos del de la izquierda si la llave coincide.

# %%
df_right = pd.merge(df_poblacion, df_ied, left_on='codigo_pais', right_on='iso_code', how='right')

print("\n--- RIGHT JOIN ---")
print("Resultado: Todos los países de 'IED', con datos de población si están disponibles.")
display(df_right)
# Out:
# --- RIGHT JOIN ---
# Resultado: Todos los países de 'IED', con datos de población si están disponibles.
#   codigo_pais  poblacion_millones iso_code  ied_millones_usd
# 0         COL               52.10      COL             17048
# 1         MEX              128.90      MEX             35292
# 2         PER               34.00      PER             11738
# 3         NaN                 NaN      ARG             15055

# %% [markdown]
# #### MERGE TIPO 4: OUTER JOIN (Unión Completa)
#
# Mantiene TODAS las filas de AMBOS DataFrames. Rellena con NaN donde no hay correspondencia.

# %%
df_outer = pd.merge(df_poblacion, df_ied, left_on='codigo_pais', right_on='iso_code', how='outer')

print("\n--- OUTER JOIN ---")
print("Resultado: Todos los países de ambos datasets.")
display(df_outer)
# Out:
# --- OUTER JOIN ---
# Resultado: Todos los países de ambos datasets.
#   codigo_pais  poblacion_millones iso_code  ied_millones_usd
# 0         NaN                 NaN      ARG         15,055.00
# 1         COL               52.10      COL         17,048.00
# 2         ECU               18.00      NaN               NaN
# 3         MEX              128.90      MEX         35,292.00
# 4         PER               34.00      PER         11,738.00

# %% [markdown]
# #### Ejercicios

# %% [markdown]
# 1. Tienes el siguiente dataframe `df_econ` con datos económicos para Colombia, México, Perú y Brasil y el dataframe `df_poblacion` que creamos previamente. Usando un `merge`, crea un nuevo DataFrame llamado `df_final` que contenga el PIB per cápita, la inflación, las exportaciones y la población para cada país. ¿Qué tipo de `join` es el más apropiado si quieres mantener todos los datos de `df_econ`?

# %%
# Datos económicos por país
df_econ = pd.DataFrame({
    'pais_iso': ['COL', 'MEX', 'PER', 'BRA'],
    'PIB_per_capita': [7917, 13954, 8316, 10296],
    'Inflacion': [6.61, 4.72, 2.01, 4.83],
    'Exportaciones': [49600, 680790, 74700, 337000]
})
df_econ
# Out:
#   pais_iso  PIB_per_capita  Inflacion  Exportaciones
# 0      COL            7917       6.61          49600
# 1      MEX           13954       4.72         680790
# 2      PER            8316       2.01          74700
# 3      BRA           10296       4.83         337000

# %%
# Respuesta:
df_final = pd.merge(df_econ, df_poblacion, left_on='pais_iso', right_on='codigo_pais', how='left')
print("DataFrame Final:")
display(df_final)
# Out:
# DataFrame Final:
#   pais_iso  PIB_per_capita  Inflacion  Exportaciones codigo_pais  \
# 0      COL            7917       6.61          49600         COL
# 1      MEX           13954       4.72         680790         MEX
# 2      PER            8316       2.01          74700         PER
# 3      BRA           10296       4.83         337000         NaN
#
#    poblacion_millones
# 0               52.10
# 1              128.90
# 2               34.00
# 3                 NaN

# %%
# La columna codigo_pais sobra, por lo que la vamos a borrar
df_final.drop(columns=['codigo_pais'], inplace=True)
df_final
# Out:
#   pais_iso  PIB_per_capita  Inflacion  Exportaciones  poblacion_millones
# 0      COL            7917       6.61          49600               52.10
# 1      MEX           13954       4.72         680790              128.90
# 2      PER            8316       2.01          74700               34.00
# 3      BRA           10296       4.83         337000                 NaN

# %% [markdown]
# 2. Tenemos estas dos tablas, una con países y su PIB, y otra con países y su índice de desarrollo humano (IDH). No todos los países están en ambas tablas. Discutan con su compañero qué tabla resultante obtendrían con un inner join vs un outer join.

# %%
# DataFrame 1: Datos de PIB por país
df_pib = pd.DataFrame({
    'pais': ['BRA', 'ARG', 'PER', 'CHL'],
    'pib_millones_usd': [2188, 604, 283, 329]
})

# DataFrame 2: Datos IDH por país
df_idh = pd.DataFrame({
    'pais': ['BRA', 'CHL', 'COL', 'PER', 'MEX'],
    'IDH': [0.786, 0.878, 0.788, 0.794, 0.789],
    'Categoría': ['Alto', 'Muy alto', 'Alto', 'Alto', 'Alto']
})

print("PIB:")
display(df_pib)
print("IDH:")
display(df_idh)
# Out:
# PIB:
#   pais  pib_millones_usd
# 0  BRA              2188
# 1  ARG               604
# 2  PER               283
# 3  CHL               329
# IDH:
#   pais  IDH Categoría
# 0  BRA 0.79      Alto
# 1  CHL 0.88  Muy alto
# 2  COL 0.79      Alto
# 3  PER 0.79      Alto
# 4  MEX 0.79      Alto

# %%
df_inner = pd.merge(df_pib, df_idh, on='pais', how='inner')
df_inner
# Out:
#   pais  pib_millones_usd  IDH Categoría
# 0  BRA              2188 0.79      Alto
# 1  PER               283 0.79      Alto
# 2  CHL               329 0.88  Muy alto

# %%
df_outer = pd.merge(df_pib, df_idh, on='pais', how='outer')
df_outer
# Out:
#   pais  pib_millones_usd  IDH Categoría
# 0  ARG            604.00  NaN       NaN
# 1  BRA          2,188.00 0.79      Alto
# 2  CHL            329.00 0.88  Muy alto
# 3  COL               NaN 0.79      Alto
# 4  MEX               NaN 0.79      Alto
# 5  PER            283.00 0.79      Alto

# %% [markdown]
# 3.  He intentado hacer un merge entre estos dos DataFrames, pero Python me da un error. ¿Quién puede ver por qué está fallando el código?

# %%
# DataFrame 1: Datos de PIB per cápita por país
df_pib_pc = pd.DataFrame({
    'país_iso': ['COL', 'MEX', 'PER', 'BRA'],
    'PIB_per_capita': [7917, 13954, 8316, 10296]
})

# DataFrame 2: Datos de inflación por país
df_inflacion = pd.DataFrame({
    'pais_iso': ['COL', 'MEX', 'PER', 'BRA'],
    'Inflacion': [6.61, 4.72, 2.01, 4.83]
})

print("PIB per cápita:")
display(df_pib_pc)
print("Inflación:")
display(df_inflacion)
# Out:
# PIB per cápita:
#   país_iso  PIB_per_capita
# 0      COL            7917
# 1      MEX           13954
# 2      PER            8316
# 3      BRA           10296
# Inflación:
#   pais_iso  Inflacion
# 0      COL       6.61
# 1      MEX       4.72
# 2      PER       2.01
# 3      BRA       4.83

# %%
df_merge = pd.merge(df_pib_pc, df_inflacion, on='pais_iso', how='inner')
df_merge
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_44933/3620455579.py in <cell line: 0>()
# ----> 1 df_merge = pd.merge(df_pib_pc, df_inflacion, on='pais_iso', how='inner')
#       2 df_merge
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1308                         #  the latter of which will raise
#    1309                         lk = cast(Hashable, lk)
# -> 1310                         left_keys.append(left._get_label_or_level_values(lk))
#    1311                         join_names.append(lk)
#    1312                     else:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#
# KeyError: 'pais_iso'

# %%
# Solución
df_merge = pd.merge(df_pib_pc, df_inflacion, left_on='país_iso', right_on='pais_iso', how='inner')
df_merge
# Out:
#   país_iso  PIB_per_capita pais_iso  Inflacion
# 0      COL            7917      COL       6.61
# 1      MEX           13954      MEX       4.72
# 2      PER            8316      PER       2.01
# 3      BRA           10296      BRA       4.83

# %% [markdown]
# 4. Y en este merge, ¿qué está fallando?

# %%
# DataFrame 1: Datos de PIB en USD por municipio
df_pib_usd = pd.DataFrame({
    'cod_municipio': ['85424', '16784', '13968', '15978'],
    'PIB_usd': [417, 1848, 283, 2188]
})

# DataFrame 2: Datos de poblacion por municipio
df_poblacion = pd.DataFrame({
    'cod_municipio': [85424, 16784, 13968, 15978],
    'Población': ['49600', '680790', '74700', '337000']
})

print("PIB en USD:")
display(df_pib_usd)
print("Población:")
display(df_poblacion)
# Out:
# PIB en USD:
#   cod_municipio  PIB_usd
# 0         85424      417
# 1         16784     1848
# 2         13968      283
# 3         15978     2188
# Población:
#    cod_municipio Población
# 0          85424     49600
# 1          16784    680790
# 2          13968     74700
# 3          15978    337000

# %%
df_combinado = pd.merge(df_pib_usd, df_poblacion, on='cod_municipio', how='inner')
df_combinado
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_44933/2182482701.py in <cell line: 0>()
# ----> 1 df_combinado = pd.merge(df_pib_usd, df_poblacion, on='cod_municipio', how='inner')
#       2 df_combinado
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     805         # validate the merge keys dtypes. We may need to coerce
#     806         # to avoid incompatible dtypes
# --> 807         self._maybe_coerce_merge_keys()
#     808
#     809         # If argument passed to validate,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in _maybe_coerce_merge_keys(self)
#    1506                     inferred_right in string_types and inferred_left not in string_types
#    1507                 ):
# -> 1508                     raise ValueError(msg)
#    1509
#    1510             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on object and int64 columns for key 'cod_municipio'. If you wish to proceed you should use pd.concat

# %%
# Solución
df_poblacion['cod_municipio'] = df_poblacion['cod_municipio'].astype(str)
df_combinado = pd.merge(df_pib_usd, df_poblacion, on='cod_municipio', how='inner')
df_combinado
# Out:
#   cod_municipio  PIB_usd Población
# 0         85424      417     49600
# 1         16784     1848    680790
# 2         13968      283     74700
# 3         15978     2188    337000

# %% [markdown]
# #### Pregunta de discusión
#
# ¿Qué harían si al intentar unir dos tablas del gobierno por "nombre del municipio", descubren que "Bogotá D.C." en una tabla se llama "Bogota" y en la otra se llama Bogotá? ¿Cómo afecta esto a los diferentes tipos de join?

# %% [markdown]
# #### Ejemplos aplicados a Economía
#
# - **Scoring de Crédito:** Unir el historial de crédito de un cliente (desde una base de datos SQL) con sus datos de redes sociales (desde una API que devuelve JSON) para crear un perfil de riesgo más completo.
#
# - **Análisis de Política Pública:** Combinar datos de ejecución presupuestal de municipios (archivo CSV del gobierno) con indicadores de pobreza del DANE (tabla en Excel) con el fin de evaluar el impacto del gasto.
#
# - **Investigación Macroeconómica:** Fusionar series de tiempo 2000-2025 sobre la inflación y el desempleo de todos los países de Latam (varios archivos de Excel) con el fin de crear un panel de datos y analizar el comportamiento de estas dos variables en el tiempo.

# %% [markdown]
# ---

# %% [markdown]
# ## Guardar / exportar datos

# %% [markdown]
# Una vez que hemos limpiado, combinado y analizado nuestros datos, el último paso es guardarlos. Esto nos permite compartir resultados o usarlos en otros programas (como R, Stata, o Tableau).

# %% [markdown]
# ### Guardar en CSV (Comma-Separated Values) - el más común

# %%
df_combinado.to_csv('Descargas/Datos_municipio.csv', encoding ='utf-8', index = False)

# %% [markdown]
# ### Guardar en TXT

# %%
df_combinado.to_csv('Descargas/Datos_municipio.txt', sep="|", decimal=',', encoding ='utf-8', index= False)

# %% [markdown]
# ### Guardar en JSON
#
# El formato 'records' es muy útil para la web y APIs. Significa que cada fila del DataFrame se convertirá en un diccionario (JSON object) dentro de una lista.
#
# indent=4: Agrega sangría de 4 espacios en el JSON para que sea más legible.
# Si no se coloca, todo el JSON queda en una sola línea.

# %%
df_final.to_json('Descargas/datos_macro_final.json', orient='records', indent=4)

# %% [markdown]
# ### Guardar en Excel

# %%
df_combinado.to_excel("Descargas/Datos_municipio.xlsx", index=False)

# %% [markdown]
# #### Guardar más de un dataframe en Excel

# %%
with pd.ExcelWriter('Descargas/Ejemplo.xlsx') as writer:
    df_combinado.to_excel(writer, sheet_name='Municipio', index=False)
    df_final.to_excel(writer, sheet_name='Macro', index=False)

# %% [markdown]
# #### Guardar un dataframe en un Excel que ya existe como una hoja adicional (mode='a)
#
# Si la hoja ya existe, la reemplaza.

# %%
with pd.ExcelWriter('Descargas/Ejemplo.xlsx', mode='a', engine='openpyxl', if_sheet_exists='replace') as writer:
    df_expo_2024.to_excel(writer, sheet_name='Expo', index = False)
